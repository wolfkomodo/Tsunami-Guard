# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import random
#%matplotlib inline

# %% [markdown]
# When I use *%matplotlib inline*, my graph becomes a black cube, so I am removing it from the code

# %%
print('testing')
# Out:
# testing

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
xlist = []
ylist = []
zlist = []
colors = []
a = random.random()
b = random.randint(1, 101)
blue_num = 0
brown_num = 0
for x in range(1, 101):
    for y in range(1, 101):
        for z in range(1, 101):
            xlist.append(x)
            ylist.append(y)
            zlist.append(z)
            if z > a*y + b:
                colors.append('blue')
                blue_num += 1
            else:
                colors.append('brown')
                brown_num += 1
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_xlim3d(0, 100);
ax.set_ylim3d(0, 100);
ax.set_zlim3d(0, 100);
ax.scatter(xlist, ylist, zlist, c=colors, marker='o')
print('Number of blue dots: %d' % blue_num)
print('Number of brown dots: %d' % brown_num)
plt.show()
# Out:
# Number of blue dots: 21000
# Number of brown dots: 979000
